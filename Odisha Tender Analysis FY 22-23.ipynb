# %%
import pandas as pd

# %%
# Load the dataset
tender_data = pd.read_csv('assignment_sheet_odisha_tender_data.csv')

# %%
# Display the dataframe
tender_data
# Out:
#                                                   Title     Location  \
# 0     Revival of Debagaon RL LIP under G B Nagar Blo...     Baripada
# 1     Revival of Purunabaripada II TW LIP under G B ...     Baripada
# 2     Revival of Purunabaripada I TW LIP under G B N...     Baripada
# 3     Revival of Kulikhiri RL LIP under Badasahi Blo...     Baripada
# 4     Revival of Chakradharpur I TW LIP under Badasa...     Baripada
# ...                                                 ...          ...
# 7041  Bathing ghat in LFB of river Nandini near vill...  Bhanjanagar
# 7042  Providing ghat in LFB of river Rushikulya near...  Bhanjanagar
# 7043  Construction of bathing ghat in LFB of river G...  Bhanjanagar
# 7044  Improvement to LFB of river Rushikulya near vi...  Bhanjanagar
# 7045  Improvement to service bank on LFB of river Gh...  Bhanjanagar
#
#                                      Organisation Chain  \
# 0     Orissa Lift Irrigation Corporation||LI BALASOR...
# 1     Orissa Lift Irrigation Corporation||LI BALASOR...
# 2     Orissa Lift Irrigation Corporation||LI BALASOR...
# 3     Orissa Lift Irrigation Corporation||LI BALASOR...
# 4     Orissa Lift Irrigation Corporation||LI BALASOR...
# ...                                                 ...
# 7041  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 7042  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 7043  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 7044  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 7045  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
#
#                        Bid Opening Place  \
# 0               EE MLI Division Baripada
# 1               EE MLI Division Baripada
# 2               EE MLI Division Baripada
# 3               EE MLI Division Baripada
# 4               EE MLI Division Baripada
# ...                                  ...
# 7041   O/o CE n BM, RVN Basin, Berhampur
# 7042   O/o CE n BM, RVN Basin, Berhampur
# 7043   O/o CE n BM, RVN Basin, Berhampur
# 7044  O/o C.E.-B.M, RVN Basin, Berhampur
# 7045   O/o CE n BM, RVN Basin, Berhampur
#
#                                        Work Description Tender Value in ₹  \
# 0     Revival of Debagaon RL LIP under G B Nagar Blo...         14,09,033
# 1     Revival of Purunabaripada II TW LIP under G B ...         15,23,123
# 2     Revival of Purunabaripada I TW LIP under G B N...         15,23,123
# 3     Revival of Kulikhiri RL LIP under Badasahi Blo...         14,04,812
# 4     Revival of Chakradharpur I TW LIP under Badasa...         15,28,009
# ...                                                 ...               ...
# 7041                       Construction of bathing ghat          4,93,000
# 7042                       Construction of bathing ghat         10,70,000
# 7043                       Construction of bathing ghat          6,32,000
# 7044                    Improvement to river EMBANKMENT         26,59,000
# 7045                        Improvement to service bank          5,22,000
#
#                            Product Category Sub category  Pincode  \
# 0     Civil Works - Lift Irrigation Schemes          NaN   757002
# 1     Civil Works - Lift Irrigation Schemes          NaN   757002
# 2     Civil Works - Lift Irrigation Schemes          NaN   757002
# 3     Civil Works - Lift Irrigation Schemes          NaN   757002
# 4     Civil Works - Lift Irrigation Schemes          NaN   757002
# ...                                     ...          ...      ...
# 7041                    Civil Works - Canal          NaN   761126
# 7042                    Civil Works - Canal          NaN   761126
# 7043                    Civil Works - Canal          NaN   761126
# 7044                   Civil Works - Others          NaN   761126
# 7045                    Civil Works - Canal          NaN   761126
#
#                              Tender Reference Number            Tender ID  \
# 0     BID ID NO. 264 (OLIC/2022-23) DATED 01.02.2023    2023_OLIC_85959_9
# 1     BID ID NO. 264 (OLIC/2022-23) DATED 01.02.2023    2023_OLIC_85959_8
# 2     BID ID NO. 264 (OLIC/2022-23) DATED 01.02.2023    2023_OLIC_85959_7
# 3     BID ID NO. 264 (OLIC/2022-23) DATED 01.02.2023    2023_OLIC_85959_6
# 4     BID ID NO. 264 (OLIC/2022-23) DATED 01.02.2023    2023_OLIC_85959_5
# ...                                              ...                  ...
# 7041                               e-BNID-09/2021-22   2021_CEBMB_72599_4
# 7042                               e-BNID-09/2021-22   2021_CEBMB_72599_3
# 7043                               e-BNID-09/2021-22   2021_CEBMB_72599_2
# 7044                             e- BNID-05/ 2021-22  2021_CEBMB_70921_11
# 7045                             e- BNID-04/ 2021-22   2021_CEBMB_70513_7
#
#       Tender Type Tender Category EMD Payable To EMD Payable At Awarded Value  \
# 0     Open Tender           Works            Nil            Nil     1,303,215
# 1     Open Tender           Works            Nil            Nil     1,504,998
# 2     Open Tender           Works            Nil            Nil     1,504,998
# 3     Open Tender           Works            Nil            Nil     1,299,310
# 4     Open Tender           Works            Nil            Nil     1,421,201
# ...           ...             ...            ...            ...           ...
# 7041  Open Tender           Works            Nil            Nil       419,036
# 7042  Open Tender           Works            Nil            Nil       906,983
# 7043  Open Tender           Works            Nil            Nil       536,994
# 7044  Open Tender           Works            Nil            Nil     2,259,915
# 7045  Open Tender           Works            Nil            Nil       443,304
#
#      Contract Date : Contract Value :  Unnamed: 18
# 0        03-Mar-2023    INR 1,409,033          NaN
# 1        03-Mar-2023    INR 1,523,123          NaN
# 2        03-Mar-2023    INR 1,523,123          NaN
# 3        03-Mar-2023    INR 1,404,812          NaN
# 4        03-Mar-2023    INR 1,528,009          NaN
# ...              ...              ...          ...
# 7041     06-Apr-2023      INR 419,036          NaN
# 7042     06-Apr-2023      INR 906,983          NaN
# 7043     06-Apr-2023      INR 536,994          NaN
# 7044     04-Apr-2023    INR 2,259,915          NaN
# 7045     29-Mar-2023      INR 443,304          NaN
#
# [7046 rows x 19 columns]

# %%
tender_data.shape
# Out:
# (7046, 19)

# %%
# Define relevant keywords for flood management related tenders
keywords = ["flood", "disaster management", "infrastructure", 
            "embankment", "culvert", "drainage", "pokhari", "pond", "river", "bridge"]

# %%
# Convert Title and Work Description columns to lowercase for case-insensitive search
tender_data['Title'] = tender_data['Title'].str.lower()
tender_data['Work Description'] = tender_data['Work Description'].str.lower()

# %%
# Apply keywords filter
flood_related_tenders = tender_data[
    tender_data['Title'].str.contains('|'.join(keywords)) |
    tender_data['Work Description'].str.contains('|'.join(keywords))
]

# %%
# Reset the index to keep the original row index as a new column
flood_related_tenders = flood_related_tenders.reset_index()

# Rename the index column for clarity
flood_related_tenders.rename(columns={'index': 'Original Index'}, inplace=True)

# %%
# Display flood related tenders dataframe
flood_related_tenders
# Out:
#      Original Index                                              Title  \
# 0               232  installation and energisation of sanopokhari i...
# 1               233  installation and energisation of sanopokhari i...
# 2               234  installation and energisation of sanopokhari i...
# 3               739  repair and restoration of jaladha balipokhari ...
# 4               777  renovation and beautification of new pond, dhu...
# ..              ...                                                ...
# 911            7041  bathing ghat in lfb of river nandini near vill...
# 912            7042  providing ghat in lfb of river rushikulya near...
# 913            7043  construction of bathing ghat in lfb of river g...
# 914            7044  improvement to lfb of river rushikulya near vi...
# 915            7045  improvement to service bank on lfb of river gh...
#
#              Location                                 Organisation Chain  \
# 0            Baripada  Orissa Lift Irrigation Corporation||LI BALASOR...
# 1            Baripada  Orissa Lift Irrigation Corporation||LI BALASOR...
# 2            Baripada  Orissa Lift Irrigation Corporation||LI BALASOR...
# 3            Jaleswar    CE RW I||RWCIRCLE-BALASORE||RWDIVISION-JALESWAR
# 4    DANAGADI, JAJPUR  Panchayati Raj and Drinking Water Department O...
# ..                ...                                                ...
# 911       Bhanjanagar  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 912       Bhanjanagar  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 913       Bhanjanagar  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 914       Bhanjanagar  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 915       Bhanjanagar  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
#
#                       Bid Opening Place  \
# 0              EE MLI Division Baripada
# 1              EE MLI Division Baripada
# 2              EE MLI Division Baripada
# 3        Rural Works Division, Jaleswar
# 4            PANCHAYAT SAMITI, DANAGADI
# ..                                  ...
# 911   O/o CE n BM, RVN Basin, Berhampur
# 912   O/o CE n BM, RVN Basin, Berhampur
# 913   O/o CE n BM, RVN Basin, Berhampur
# 914  O/o C.E.-B.M, RVN Basin, Berhampur
# 915   O/o CE n BM, RVN Basin, Berhampur
#
#                                       Work Description Tender Value in ₹  \
# 0    installation and energisation of sanopokhari i...         21,71,002
# 1    installation and energisation of sanopokhari i...         19,10,867
# 2    installation and energisation of sanopokhari i...         19,52,578
# 3                                            road work          1,36,937
# 4           renovation and beautification of new pond,         24,12,058
# ..                                                 ...               ...
# 911                       construction of bathing ghat          4,93,000
# 912                       construction of bathing ghat         10,70,000
# 913                       construction of bathing ghat          6,32,000
# 914                    improvement to river embankment         26,59,000
# 915                        improvement to service bank          5,22,000
#
#                           Product Category Sub category  Pincode  \
# 0    Civil Works - Lift Irrigation Schemes          NaN   757002
# 1    Civil Works - Lift Irrigation Schemes          NaN   757002
# 2    Civil Works - Lift Irrigation Schemes          NaN   757002
# 3                      Civil Works - Roads          NaN   756086
# 4                     Civil Works - Others          NaN   755026
# ..                                     ...          ...      ...
# 911                    Civil Works - Canal          NaN   761126
# 912                    Civil Works - Canal          NaN   761126
# 913                    Civil Works - Canal          NaN   761126
# 914                   Civil Works - Others          NaN   761126
# 915                    Civil Works - Canal          NaN   761126
#
#                              Tender Reference Number            Tender ID  \
# 0    BID ID NO. 3764 (OLIC/2021-22) DATED 18.12.2021   2021_OLIC_75071_82
# 1    BID ID NO. 3764 (OLIC/2021-22) DATED 18.12.2021   2021_OLIC_75071_81
# 2    BID ID NO. 3764 (OLIC/2021-22) DATED 18.12.2021   2021_OLIC_75071_80
# 3                              SE/RW/Jls- 04/2022-23  2022_CERWI_83508_22
# 4                                01 DANAGADI/2022-23   2023_PRDNG_86394_1
# ..                                               ...                  ...
# 911                                e-BNID-09/2021-22   2021_CEBMB_72599_4
# 912                                e-BNID-09/2021-22   2021_CEBMB_72599_3
# 913                                e-BNID-09/2021-22   2021_CEBMB_72599_2
# 914                              e- BNID-05/ 2021-22  2021_CEBMB_70921_11
# 915                              e- BNID-04/ 2021-22   2021_CEBMB_70513_7
#
#      Tender Type Tender Category EMD Payable To EMD Payable At Awarded Value  \
# 0    Open Tender           Works            Nil            Nil     2,171,002
# 1    Open Tender           Works            Nil            Nil     1,910,867
# 2    Open Tender           Works            Nil            Nil     1,952,578
# 3    Open Tender           Works            Nil            Nil       116,410
# 4    Open Tender           Works            Nil            Nil     2,050,490
# ..           ...             ...            ...            ...           ...
# 911  Open Tender           Works            Nil            Nil       419,036
# 912  Open Tender           Works            Nil            Nil       906,983
# 913  Open Tender           Works            Nil            Nil       536,994
# 914  Open Tender           Works            Nil            Nil     2,259,915
# 915  Open Tender           Works            Nil            Nil       443,304
#
#     Contract Date : Contract Value :  Unnamed: 18
# 0       04-Nov-2022    INR 2,171,002          NaN
# 1       04-Nov-2022    INR 1,910,867          NaN
# 2       04-Nov-2022    INR 1,952,578          NaN
# 3       15-Feb-2023      INR 136,937          NaN
# 4       10-Apr-2023    INR 2,050,490          NaN
# ..              ...              ...          ...
# 911     06-Apr-2023      INR 419,036          NaN
# 912     06-Apr-2023      INR 906,983          NaN
# 913     06-Apr-2023      INR 536,994          NaN
# 914     04-Apr-2023    INR 2,259,915          NaN
# 915     29-Mar-2023      INR 443,304          NaN
#
# [916 rows x 20 columns]

# %%
# Reload the original dataset to get Title and Work Description in original case
tender_data_original = pd.read_csv('assignment_sheet_odisha_tender_data.csv')

# %%
tender_data_original
# Out:
#                                                   Title     Location  \
# 0     Revival of Debagaon RL LIP under G B Nagar Blo...     Baripada
# 1     Revival of Purunabaripada II TW LIP under G B ...     Baripada
# 2     Revival of Purunabaripada I TW LIP under G B N...     Baripada
# 3     Revival of Kulikhiri RL LIP under Badasahi Blo...     Baripada
# 4     Revival of Chakradharpur I TW LIP under Badasa...     Baripada
# ...                                                 ...          ...
# 7041  Bathing ghat in LFB of river Nandini near vill...  Bhanjanagar
# 7042  Providing ghat in LFB of river Rushikulya near...  Bhanjanagar
# 7043  Construction of bathing ghat in LFB of river G...  Bhanjanagar
# 7044  Improvement to LFB of river Rushikulya near vi...  Bhanjanagar
# 7045  Improvement to service bank on LFB of river Gh...  Bhanjanagar
#
#                                      Organisation Chain  \
# 0     Orissa Lift Irrigation Corporation||LI BALASOR...
# 1     Orissa Lift Irrigation Corporation||LI BALASOR...
# 2     Orissa Lift Irrigation Corporation||LI BALASOR...
# 3     Orissa Lift Irrigation Corporation||LI BALASOR...
# 4     Orissa Lift Irrigation Corporation||LI BALASOR...
# ...                                                 ...
# 7041  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 7042  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 7043  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 7044  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 7045  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
#
#                        Bid Opening Place  \
# 0               EE MLI Division Baripada
# 1               EE MLI Division Baripada
# 2               EE MLI Division Baripada
# 3               EE MLI Division Baripada
# 4               EE MLI Division Baripada
# ...                                  ...
# 7041   O/o CE n BM, RVN Basin, Berhampur
# 7042   O/o CE n BM, RVN Basin, Berhampur
# 7043   O/o CE n BM, RVN Basin, Berhampur
# 7044  O/o C.E.-B.M, RVN Basin, Berhampur
# 7045   O/o CE n BM, RVN Basin, Berhampur
#
#                                        Work Description Tender Value in ₹  \
# 0     Revival of Debagaon RL LIP under G B Nagar Blo...         14,09,033
# 1     Revival of Purunabaripada II TW LIP under G B ...         15,23,123
# 2     Revival of Purunabaripada I TW LIP under G B N...         15,23,123
# 3     Revival of Kulikhiri RL LIP under Badasahi Blo...         14,04,812
# 4     Revival of Chakradharpur I TW LIP under Badasa...         15,28,009
# ...                                                 ...               ...
# 7041                       Construction of bathing ghat          4,93,000
# 7042                       Construction of bathing ghat         10,70,000
# 7043                       Construction of bathing ghat          6,32,000
# 7044                    Improvement to river EMBANKMENT         26,59,000
# 7045                        Improvement to service bank          5,22,000
#
#                            Product Category Sub category  Pincode  \
# 0     Civil Works - Lift Irrigation Schemes          NaN   757002
# 1     Civil Works - Lift Irrigation Schemes          NaN   757002
# 2     Civil Works - Lift Irrigation Schemes          NaN   757002
# 3     Civil Works - Lift Irrigation Schemes          NaN   757002
# 4     Civil Works - Lift Irrigation Schemes          NaN   757002
# ...                                     ...          ...      ...
# 7041                    Civil Works - Canal          NaN   761126
# 7042                    Civil Works - Canal          NaN   761126
# 7043                    Civil Works - Canal          NaN   761126
# 7044                   Civil Works - Others          NaN   761126
# 7045                    Civil Works - Canal          NaN   761126
#
#                              Tender Reference Number            Tender ID  \
# 0     BID ID NO. 264 (OLIC/2022-23) DATED 01.02.2023    2023_OLIC_85959_9
# 1     BID ID NO. 264 (OLIC/2022-23) DATED 01.02.2023    2023_OLIC_85959_8
# 2     BID ID NO. 264 (OLIC/2022-23) DATED 01.02.2023    2023_OLIC_85959_7
# 3     BID ID NO. 264 (OLIC/2022-23) DATED 01.02.2023    2023_OLIC_85959_6
# 4     BID ID NO. 264 (OLIC/2022-23) DATED 01.02.2023    2023_OLIC_85959_5
# ...                                              ...                  ...
# 7041                               e-BNID-09/2021-22   2021_CEBMB_72599_4
# 7042                               e-BNID-09/2021-22   2021_CEBMB_72599_3
# 7043                               e-BNID-09/2021-22   2021_CEBMB_72599_2
# 7044                             e- BNID-05/ 2021-22  2021_CEBMB_70921_11
# 7045                             e- BNID-04/ 2021-22   2021_CEBMB_70513_7
#
#       Tender Type Tender Category EMD Payable To EMD Payable At Awarded Value  \
# 0     Open Tender           Works            Nil            Nil     1,303,215
# 1     Open Tender           Works            Nil            Nil     1,504,998
# 2     Open Tender           Works            Nil            Nil     1,504,998
# 3     Open Tender           Works            Nil            Nil     1,299,310
# 4     Open Tender           Works            Nil            Nil     1,421,201
# ...           ...             ...            ...            ...           ...
# 7041  Open Tender           Works            Nil            Nil       419,036
# 7042  Open Tender           Works            Nil            Nil       906,983
# 7043  Open Tender           Works            Nil            Nil       536,994
# 7044  Open Tender           Works            Nil            Nil     2,259,915
# 7045  Open Tender           Works            Nil            Nil       443,304
#
#      Contract Date : Contract Value :  Unnamed: 18
# 0        03-Mar-2023    INR 1,409,033          NaN
# 1        03-Mar-2023    INR 1,523,123          NaN
# 2        03-Mar-2023    INR 1,523,123          NaN
# 3        03-Mar-2023    INR 1,404,812          NaN
# 4        03-Mar-2023    INR 1,528,009          NaN
# ...              ...              ...          ...
# 7041     06-Apr-2023      INR 419,036          NaN
# 7042     06-Apr-2023      INR 906,983          NaN
# 7043     06-Apr-2023      INR 536,994          NaN
# 7044     04-Apr-2023    INR 2,259,915          NaN
# 7045     29-Mar-2023      INR 443,304          NaN
#
# [7046 rows x 19 columns]

# %%
# Restore original Title and Work Description into the filtered flood-related tenders
flood_related_tenders['Title'] = tender_data_original['Title'].iloc[flood_related_tenders.index]
flood_related_tenders['Work Description'] = tender_data_original['Work Description'].iloc[flood_related_tenders.index]

# %%
flood_related_tenders
# Out:
#      Original Index                                              Title  \
# 0               232  Revival of Debagaon RL LIP under G B Nagar Blo...
# 1               233  Revival of Purunabaripada II TW LIP under G B ...
# 2               234  Revival of Purunabaripada I TW LIP under G B N...
# 3               739  Revival of Kulikhiri RL LIP under Badasahi Blo...
# 4               777  Revival of Chakradharpur I TW LIP under Badasa...
# ..              ...                                                ...
# 911            7041  Construction Of Market Complex Room At 1st Flo...
# 912            7042  Construction Of Community Manadap at Bada Indi...
# 913            7043  Formation of the existing road leading from Da...
# 914            7044  Development of Alatuma High School Playground ...
# 915            7045  Construction Of N.A.C office Extension Buildin...
#
#              Location                                 Organisation Chain  \
# 0            Baripada  Orissa Lift Irrigation Corporation||LI BALASOR...
# 1            Baripada  Orissa Lift Irrigation Corporation||LI BALASOR...
# 2            Baripada  Orissa Lift Irrigation Corporation||LI BALASOR...
# 3            Jaleswar    CE RW I||RWCIRCLE-BALASORE||RWDIVISION-JALESWAR
# 4    DANAGADI, JAJPUR  Panchayati Raj and Drinking Water Department O...
# ..                ...                                                ...
# 911       Bhanjanagar  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 912       Bhanjanagar  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 913       Bhanjanagar  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 914       Bhanjanagar  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 915       Bhanjanagar  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
#
#                       Bid Opening Place  \
# 0              EE MLI Division Baripada
# 1              EE MLI Division Baripada
# 2              EE MLI Division Baripada
# 3        Rural Works Division, Jaleswar
# 4            PANCHAYAT SAMITI, DANAGADI
# ..                                  ...
# 911   O/o CE n BM, RVN Basin, Berhampur
# 912   O/o CE n BM, RVN Basin, Berhampur
# 913   O/o CE n BM, RVN Basin, Berhampur
# 914  O/o C.E.-B.M, RVN Basin, Berhampur
# 915   O/o CE n BM, RVN Basin, Berhampur
#
#                                       Work Description Tender Value in ₹  \
# 0    Revival of Debagaon RL LIP under G B Nagar Blo...         21,71,002
# 1    Revival of Purunabaripada II TW LIP under G B ...         19,10,867
# 2    Revival of Purunabaripada I TW LIP under G B N...         19,52,578
# 3    Revival of Kulikhiri RL LIP under Badasahi Blo...          1,36,937
# 4    Revival of Chakradharpur I TW LIP under Badasa...         24,12,058
# ..                                                 ...               ...
# 911  Construction Of Market Complex Room At 1st Flo...          4,93,000
# 912  Construction Of Community Manadap at Bada Indi...         10,70,000
# 913  Formation of the existing road leading from Da...          6,32,000
# 914  Development of Alatuma High School Playground ...         26,59,000
# 915  Construction Of N.A.C office Extension Buildin...          5,22,000
#
#                           Product Category Sub category  Pincode  \
# 0    Civil Works - Lift Irrigation Schemes          NaN   757002
# 1    Civil Works - Lift Irrigation Schemes          NaN   757002
# 2    Civil Works - Lift Irrigation Schemes          NaN   757002
# 3                      Civil Works - Roads          NaN   756086
# 4                     Civil Works - Others          NaN   755026
# ..                                     ...          ...      ...
# 911                    Civil Works - Canal          NaN   761126
# 912                    Civil Works - Canal          NaN   761126
# 913                    Civil Works - Canal          NaN   761126
# 914                   Civil Works - Others          NaN   761126
# 915                    Civil Works - Canal          NaN   761126
#
#                              Tender Reference Number            Tender ID  \
# 0    BID ID NO. 3764 (OLIC/2021-22) DATED 18.12.2021   2021_OLIC_75071_82
# 1    BID ID NO. 3764 (OLIC/2021-22) DATED 18.12.2021   2021_OLIC_75071_81
# 2    BID ID NO. 3764 (OLIC/2021-22) DATED 18.12.2021   2021_OLIC_75071_80
# 3                              SE/RW/Jls- 04/2022-23  2022_CERWI_83508_22
# 4                                01 DANAGADI/2022-23   2023_PRDNG_86394_1
# ..                                               ...                  ...
# 911                                e-BNID-09/2021-22   2021_CEBMB_72599_4
# 912                                e-BNID-09/2021-22   2021_CEBMB_72599_3
# 913                                e-BNID-09/2021-22   2021_CEBMB_72599_2
# 914                              e- BNID-05/ 2021-22  2021_CEBMB_70921_11
# 915                              e- BNID-04/ 2021-22   2021_CEBMB_70513_7
#
#      Tender Type Tender Category EMD Payable To EMD Payable At Awarded Value  \
# 0    Open Tender           Works            Nil            Nil     2,171,002
# 1    Open Tender           Works            Nil            Nil     1,910,867
# 2    Open Tender           Works            Nil            Nil     1,952,578
# 3    Open Tender           Works            Nil            Nil       116,410
# 4    Open Tender           Works            Nil            Nil     2,050,490
# ..           ...             ...            ...            ...           ...
# 911  Open Tender           Works            Nil            Nil       419,036
# 912  Open Tender           Works            Nil            Nil       906,983
# 913  Open Tender           Works            Nil            Nil       536,994
# 914  Open Tender           Works            Nil            Nil     2,259,915
# 915  Open Tender           Works            Nil            Nil       443,304
#
#     Contract Date : Contract Value :  Unnamed: 18
# 0       04-Nov-2022    INR 2,171,002          NaN
# 1       04-Nov-2022    INR 1,910,867          NaN
# 2       04-Nov-2022    INR 1,952,578          NaN
# 3       15-Feb-2023      INR 136,937          NaN
# 4       10-Apr-2023    INR 2,050,490          NaN
# ..              ...              ...          ...
# 911     06-Apr-2023      INR 419,036          NaN
# 912     06-Apr-2023      INR 906,983          NaN
# 913     06-Apr-2023      INR 536,994          NaN
# 914     04-Apr-2023    INR 2,259,915          NaN
# 915     29-Mar-2023      INR 443,304          NaN
#
# [916 rows x 20 columns]

# %%
# Export the flood-related tenders to a CSV file
flood_related_tenders.to_csv('flood_related_tenders.csv', index=False)

# %%
# Count tenders by department
department_counts = flood_related_tenders['Organisation Chain'].value_counts()

# %%
# Convert the count to a aataframe for easy visualization
department_counts_df = department_counts.reset_index()
department_counts_df.columns = ['Department', 'Tender Count']

# %%
department_counts_df
# Out:
#                                             Department  Tender Count
# 0    CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...           280
# 1        OPEPA Bhubaneswar||Samagra Shiksha Sundargarh           158
# 2    CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...            27
# 3       Orissa Bridge and Construction Corporation Ltd            19
# 4    CE,Drainage,Cuttack||SE Drainage Circle Bhuban...            17
# ..                                                 ...           ...
# 109  EIC-CIVIL||SERNB-CIRCLE-NORTHERN||EERNB-DIVN-J...             1
# 110       ST and SC Development Deptt||ITDA Rairangpur             1
# 111            Municipal Bodies||Balangir Municipality             1
# 112         CE,Minor Irrigation,BBSR||SENMIC-SAMBALPUR             1
# 113  CCE,Upper Kolab Project,Jeypore||CCE,Upper Kol...             1
#
# [114 rows x 2 columns]

# %%
# Export department counts dataframe to a CSV
department_counts_df.to_csv('department_counts.csv', index=False)

# %%
# Save Top 5 departments by tender count in a dataframe
top_5_departments = department_counts_df.head(5)

# %%
# Display Top 5 departments dataframe
top_5_departments
# Out:
#                                           Department  Tender Count
# 0  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...           280
# 1      OPEPA Bhubaneswar||Samagra Shiksha Sundargarh           158
# 2  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...            27
# 3     Orissa Bridge and Construction Corporation Ltd            19
# 4  CE,Drainage,Cuttack||SE Drainage Circle Bhuban...            17

# %%
# Count project types by Tender Category
category_counts = flood_related_tenders['Tender Category'].value_counts()

# %%
# Convert to dataframe for easy visualization
category_counts_df = category_counts.reset_index()
category_counts_df.columns = ['Category', 'Count']

# %%
category_counts_df
# Out:
#    Category  Count
# 0     Works    915
# 1  Services      1

# %%
# Convert 'Tender Value in ₹' to numeric by removing commas and converting to float
flood_related_tenders['Tender Value in ₹'] = flood_related_tenders['Tender Value in ₹'].str.replace(',', '').astype(float)

# Standardize 'Location' to lowercase for consistent grouping
flood_related_tenders['Location'] = flood_related_tenders['Location'].str.lower()

# Group by 'Location' and calculate both the total Tender Value and Tender Count
region_funding = flood_related_tenders.groupby('Location').agg(
    Tender_Value=('Tender Value in ₹', 'sum'),
    Tender_Count=('Tender Value in ₹', 'size')  # Counts the number of entries per location
).reset_index()

# Sort by total funding value
region_funding_sorted = region_funding.sort_values(by='Tender_Value', ascending=False)

# Capitalize the 'Location' names
region_funding_sorted['Location'] = region_funding_sorted['Location'].str.title()

# Format 'Tender_Value' with commas for rupee format
region_funding_sorted['Tender_Value'] = region_funding_sorted['Tender_Value'].apply(lambda x: f"{x:,.2f}")

# Rename columns for clarity
region_funding_sorted.rename(columns={'Tender_Value': 'Tender Value in ₹', 'Tender_Count': 'Tender Count'}, inplace=True)

# Export funding by region dataframe to a CSV
region_funding_sorted.to_csv('flood_related_region_funding_sorted.csv', index=False)

# %%
region_funding_sorted
# Out:
#                                      Location Tender Value in ₹  Tender Count
# 195                                Sundargarh  2,467,096,415.00           164
# 13                Balimela.Malkanagiri,Odisha    901,395,438.00             1
# 35                                Bhanjanagar    282,996,794.00           244
# 176                Rajanagar Block,Kendrapara    244,498,368.00             1
# 4                                        Aska    196,424,801.00            40
# ..                                        ...               ...           ...
# 8                       Balangir Municipality        300,000.00             1
# 150                   O/O Serw Division Boudh        130,362.00             1
# 203                                 Ward No-4         97,740.00             1
# 84   Gochara (Janakdihi) In Sambalpur, Odisha              1.00             1
# 100                In The District Of Cuttack              0.00             1
#
# [204 rows x 3 columns]

# %%
flood_related_tenders
# Out:
#      Original Index                                              Title  \
# 0               232  Revival of Debagaon RL LIP under G B Nagar Blo...
# 1               233  Revival of Purunabaripada II TW LIP under G B ...
# 2               234  Revival of Purunabaripada I TW LIP under G B N...
# 3               739  Revival of Kulikhiri RL LIP under Badasahi Blo...
# 4               777  Revival of Chakradharpur I TW LIP under Badasa...
# ..              ...                                                ...
# 911            7041  Construction Of Market Complex Room At 1st Flo...
# 912            7042  Construction Of Community Manadap at Bada Indi...
# 913            7043  Formation of the existing road leading from Da...
# 914            7044  Development of Alatuma High School Playground ...
# 915            7045  Construction Of N.A.C office Extension Buildin...
#
#              Location                                 Organisation Chain  \
# 0            baripada  Orissa Lift Irrigation Corporation||LI BALASOR...
# 1            baripada  Orissa Lift Irrigation Corporation||LI BALASOR...
# 2            baripada  Orissa Lift Irrigation Corporation||LI BALASOR...
# 3            jaleswar    CE RW I||RWCIRCLE-BALASORE||RWDIVISION-JALESWAR
# 4    danagadi, jajpur  Panchayati Raj and Drinking Water Department O...
# ..                ...                                                ...
# 911       bhanjanagar  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 912       bhanjanagar  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 913       bhanjanagar  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 914       bhanjanagar  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
# 915       bhanjanagar  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...
#
#                       Bid Opening Place  \
# 0              EE MLI Division Baripada
# 1              EE MLI Division Baripada
# 2              EE MLI Division Baripada
# 3        Rural Works Division, Jaleswar
# 4            PANCHAYAT SAMITI, DANAGADI
# ..                                  ...
# 911   O/o CE n BM, RVN Basin, Berhampur
# 912   O/o CE n BM, RVN Basin, Berhampur
# 913   O/o CE n BM, RVN Basin, Berhampur
# 914  O/o C.E.-B.M, RVN Basin, Berhampur
# 915   O/o CE n BM, RVN Basin, Berhampur
#
#                                       Work Description  Tender Value in ₹  \
# 0    Revival of Debagaon RL LIP under G B Nagar Blo...          2171002.0
# 1    Revival of Purunabaripada II TW LIP under G B ...          1910867.0
# 2    Revival of Purunabaripada I TW LIP under G B N...          1952578.0
# 3    Revival of Kulikhiri RL LIP under Badasahi Blo...           136937.0
# 4    Revival of Chakradharpur I TW LIP under Badasa...          2412058.0
# ..                                                 ...                ...
# 911  Construction Of Market Complex Room At 1st Flo...           493000.0
# 912  Construction Of Community Manadap at Bada Indi...          1070000.0
# 913  Formation of the existing road leading from Da...           632000.0
# 914  Development of Alatuma High School Playground ...          2659000.0
# 915  Construction Of N.A.C office Extension Buildin...           522000.0
#
#                           Product Category Sub category  Pincode  \
# 0    Civil Works - Lift Irrigation Schemes          NaN   757002
# 1    Civil Works - Lift Irrigation Schemes          NaN   757002
# 2    Civil Works - Lift Irrigation Schemes          NaN   757002
# 3                      Civil Works - Roads          NaN   756086
# 4                     Civil Works - Others          NaN   755026
# ..                                     ...          ...      ...
# 911                    Civil Works - Canal          NaN   761126
# 912                    Civil Works - Canal          NaN   761126
# 913                    Civil Works - Canal          NaN   761126
# 914                   Civil Works - Others          NaN   761126
# 915                    Civil Works - Canal          NaN   761126
#
#                              Tender Reference Number            Tender ID  \
# 0    BID ID NO. 3764 (OLIC/2021-22) DATED 18.12.2021   2021_OLIC_75071_82
# 1    BID ID NO. 3764 (OLIC/2021-22) DATED 18.12.2021   2021_OLIC_75071_81
# 2    BID ID NO. 3764 (OLIC/2021-22) DATED 18.12.2021   2021_OLIC_75071_80
# 3                              SE/RW/Jls- 04/2022-23  2022_CERWI_83508_22
# 4                                01 DANAGADI/2022-23   2023_PRDNG_86394_1
# ..                                               ...                  ...
# 911                                e-BNID-09/2021-22   2021_CEBMB_72599_4
# 912                                e-BNID-09/2021-22   2021_CEBMB_72599_3
# 913                                e-BNID-09/2021-22   2021_CEBMB_72599_2
# 914                              e- BNID-05/ 2021-22  2021_CEBMB_70921_11
# 915                              e- BNID-04/ 2021-22   2021_CEBMB_70513_7
#
#      Tender Type Tender Category EMD Payable To EMD Payable At Awarded Value  \
# 0    Open Tender           Works            Nil            Nil     2,171,002
# 1    Open Tender           Works            Nil            Nil     1,910,867
# 2    Open Tender           Works            Nil            Nil     1,952,578
# 3    Open Tender           Works            Nil            Nil       116,410
# 4    Open Tender           Works            Nil            Nil     2,050,490
# ..           ...             ...            ...            ...           ...
# 911  Open Tender           Works            Nil            Nil       419,036
# 912  Open Tender           Works            Nil            Nil       906,983
# 913  Open Tender           Works            Nil            Nil       536,994
# 914  Open Tender           Works            Nil            Nil     2,259,915
# 915  Open Tender           Works            Nil            Nil       443,304
#
#     Contract Date : Contract Value :  Unnamed: 18
# 0       04-Nov-2022    INR 2,171,002          NaN
# 1       04-Nov-2022    INR 1,910,867          NaN
# 2       04-Nov-2022    INR 1,952,578          NaN
# 3       15-Feb-2023      INR 136,937          NaN
# 4       10-Apr-2023    INR 2,050,490          NaN
# ..              ...              ...          ...
# 911     06-Apr-2023      INR 419,036          NaN
# 912     06-Apr-2023      INR 906,983          NaN
# 913     06-Apr-2023      INR 536,994          NaN
# 914     04-Apr-2023    INR 2,259,915          NaN
# 915     29-Mar-2023      INR 443,304          NaN
#
# [916 rows x 20 columns]

# %%
# Convert Awarded Value to numeric
flood_related_tenders['Awarded Value'] = flood_related_tenders['Awarded Value'].str.replace(',', '').astype(float)

# %%
# Sort by Awarded Value to find large-scale projects
large_projects = flood_related_tenders.sort_values(by='Awarded Value', ascending=False)

# %%
# Convert Awarded Value to rupee
large_projects['Awarded Value'] = large_projects['Awarded Value'].apply(lambda x: f"{x:,.2f}")

# %%
large_projects
# Out:
#      Original Index                                              Title  \
# 8               944  Revival of Darkholi_I TW LIP under Kuliana Blo...
# 323            5472  Installation and Energisation of Sananachhana ...
# 376            5793  Installation and Energisation of Bainchanuagao...
# 339            5724  Installation and Energisation of Chuhat II TW ...
# 624            6042  New Installation and Energisation including po...
# ..              ...                                                ...
# 786            6327          SUB CENTRE AT BALICHANDRAPUR OF BITANA GP
# 681            6103  New Installation and Energisation including po...
# 16             1090  Revival of MADHUPUR-III LIP under LANJIGARH Bl...
# 781            6322     Construction of Sub centre Building at Erancha
# 17             1176  Revival of LAKTAKHAMAN-II LIP under LANJIGARH ...
#
#                                      Location  \
# 8                 balimela.malkanagiri,odisha
# 323  gochara (janakdihi) in sambalpur, odisha
# 376                rajanagar block,kendrapara
# 339       ersama block,jagatsinghpur district
# 624                                 kalahandi
# ..                                        ...
# 786                                     angul
# 681                   o/o serw division boudh
# 16                                 kosagumuda
# 781                                 ward no-4
# 17                                   jaleswar
#
#                                     Organisation Chain  \
# 8           ODISHA CONSTRUCTION CORPORATION LTD||CIVIL
# 323                               CE-BM,UM Basin,Burla
# 376                                CE,Drainage,Cuttack
# 339           CE,Drainage,Cuttack||SE,Drainage,Cuttack
# 624                   EIC-CIVIL||SERNB-CIRCLE-BOLANGIR
# ..                                                 ...
# 786               Municipal Bodies||Angul Municipality
# 681      CE RW I||RWCIRCLE-BERHAMPUR||RWDIVISION-BOUDH
# 16   CE RW I||RWCIRCLE-SUNABEDA||RWDIVISION-NAWARAN...
# 781                     Municipal Bodies||Kuchinda NAC
# 17     CE RW I||RWCIRCLE-BALASORE||RWDIVISION-JALESWAR
#
#                                     Bid Opening Place  \
# 8                             HEAD OFFICE OF OCC LTD.
# 323                      O/o CEBM, MB, Burla (Online)
# 376          o/o-the Chief Engineer,Drainage,,Cuttack
# 339                       O/o the CE,Drainage,Cuttack
# 624      O/o CCE, Balangir (R and B) Circle, Balangir
# ..                                                ...
# 786  O/O Executive Officer, Angul Municipality, Angul
# 681                           O/o SERW Division Boudh
# 16             O/o the SE, RW Division-I, Nabarangpur
# 781      OFFICE OF THE EXECUTIVE OFFICER NAC KUCHINDA
# 17                             R.W.Division, Jaleswar
#
#                                       Work Description  Tender Value in ₹  \
# 8    Revival of Darkholi_I TW LIP under Kuliana Blo...        901395438.0
# 323  Installation and Energisation of Sananachhana ...                1.0
# 376  Installation and Energisation of Bainchanuagao...        244498368.0
# 339  Installation and Energisation of Chuhat II TW ...        104664838.0
# 624  New Construction of Head works Distribution Sy...         91999939.0
# ..                                                 ...                ...
# 786          SUB CENTRE AT BALICHANDRAPUR OF BITANA GP           136600.0
# 681  New Construction of Head works Distribution Sy...           130362.0
# 16   Construction of Head works installation and En...           126990.0
# 781  Construction of Day-care Sub centre cum Wellne...            97740.0
# 17   Construction of Head works installation and En...            35217.0
#
#           Product Category                                      Sub category  \
# 8     Civil Works - Others                                               NaN
# 323  Civil Works - Bridges  Bridge cum Barrage (In-stream Storage Structure)
# 376   Civil Works - Others                                               NaN
# 339   Civil Works - Others                                               NaN
# 624  Civil Works - Bridges                                               NaN
# ..                     ...                                               ...
# 786   Civil Works - Others                                               NaN
# 681    Civil Works - Roads                                               NaN
# 16     Civil Works - Roads                                               NaN
# 781   Civil Works - Others                                               NaN
# 17     Civil Works - Roads                                               NaN
#
#      Pincode                            Tender Reference Number  \
# 8     764051  e-procurement Notice No.39/OCCL/2022-23 (on-line)
# 323   768222                             UMB-04/2021-22(ONLINE)
# 376   754225                               CE-DR-CTC-01/2022-23
# 339   754139                               CE-DR-CTC-02/2021-22
# 624   762110                       CCE (R and B) BGR-05-2021-22
# ..       ...                                                ...
# 786   759122                                 EO/AGLM-09/2021-22
# 681   762014       Online Tender/20/EERW Division Boudh/2022-23
# 16    764061                          EERWNGP-Online-10/2022-23
# 781   768222                                KCDA/NAC-11/2021-22
# 17    756086                               SE/RW/Jls-07/2022-23
#
#                Tender ID               Tender Type Tender Category  \
# 8      2023_OCCL_85430_1               Open Tender           Works
# 323   2021_CEBBU_71376_1  National Competitive Bid           Works
# 376    2022_CEDC_76817_1  National Competitive Bid           Works
# 339    2022_CEDC_75544_1  National Competitive Bid           Works
# 624   2021_EICCL_70888_1  National Competitive Bid           Works
# ..                   ...                       ...             ...
# 786   2021_ORULB_70459_1               Open Tender           Works
# 681   2023_CERWI_86616_1               Open Tender           Works
# 16    2023_CERWI_86352_2               Open Tender           Works
# 781  2021_ORULB_72707_24               Open Tender           Works
# 17   2023_CERWI_85692_24               Open Tender           Works
#
#     EMD Payable To EMD Payable At   Awarded Value Contract Date :  \
# 8              Nil            Nil  856,415,806.00     02-Mar-2023
# 323            Nil            Nil  348,500,000.00     18-Jun-2022
# 376            Nil            Nil  207,848,063.00     06-Feb-2023
# 339            Nil            Nil   88,975,579.00     21-Oct-2022
# 624            Nil            Nil   78,209,148.00     13-May-2022
# ..             ...            ...             ...             ...
# 786            Nil            Nil      116,130.00     17-Jan-2023
# 681            Nil            Nil      110,820.00     18-Apr-2023
# 16             Nil            Nil      107,954.00     23-Mar-2023
# 781            Nil            Nil       83,039.91     28-Oct-2022
# 17             Nil            Nil       29,937.57     04-Mar-2023
#
#        Contract Value :  Unnamed: 18
# 8    INR 901,395,438.22          NaN
# 323     INR 348,500,000          NaN
# 376     INR 207,848,063          NaN
# 339      INR 88,975,579          NaN
# 624      INR 78,209,148          NaN
# ..                  ...          ...
# 786      INR 136,607.92          NaN
# 681         INR 110,820          NaN
# 16       INR 126,989.74          NaN
# 781       INR 83,039.91          NaN
# 17         INR 35216.53          NaN
#
# [916 rows x 20 columns]

# %%
# Export sorted large projects dataframe to CSV
large_projects.to_csv('large_projects.csv', index=False)

# %%
# Identify departments that handle the largest budgets for flood related projects
department_spending = flood_related_tenders.groupby('Organisation Chain')['Awarded Value'].sum().reset_index()
department_spending_sorted = department_spending.sort_values(by='Awarded Value', ascending=False)

# %%
# Convert Awarded Value to rupee
department_spending_sorted['Awarded Value'] = department_spending_sorted['Awarded Value'].apply(lambda x: f"{x:,.2f}")
department_spending_sorted
# Out:
#                                    Organisation Chain     Awarded Value
# 94      OPEPA Bhubaneswar||Samagra Shiksha Sundargarh  2,201,912,440.07
# 48  CE-BM,RVN Basin,Berhampur||S.E. Southern Irr. ...  1,099,010,798.72
# 93         ODISHA CONSTRUCTION CORPORATION LTD||CIVIL    877,460,808.00
# 33  CE,Drainage,Cuttack||SE Drainage Circle Bhuban...    440,261,111.00
# 52                               CE-BM,UM Basin,Burla    348,500,000.00
# ..                                                ...               ...
# 79            Municipal Bodies||Balasore Municipality        683,220.30
# 24  CE RW I||RWCIRCLE-KENDRAPARA||RWDIVISION-KENDR...        449,947.00
# 13   CE RW I||RWCIRCLE-BARIPADA||RW Division Baripada        375,871.84
# 78            Municipal Bodies||Balangir Municipality        227,503.92
# 15      CE RW I||RWCIRCLE-BERHAMPUR||RWDIVISION-BOUDH        110,820.00
#
# [114 rows x 2 columns]

# %%
# Export department spending dataframe to CSV
department_spending_sorted.to_csv('department_spending.csv', index=False)

# %%
# Import matplotlib
import matplotlib.pyplot as plt

# Plot flood related tenders as a percentage of total tenders
plt.style.use("fivethirtyeight")

slices = [7046, 916]
labels = ["Total tenders", "Flood related tenders"]
colors = ["#23B2A7", "#6C75E1"] 
explode = [0,0.1]
plt.pie(slices, labels=labels, colors=colors, explode=explode, shadow=True, autopct="%1.1f%%", wedgeprops={"edgecolor": "black"})

plt.title("Distribution of Tenders in Odisha (FY 2022-23)")
plt.tight_layout()
plt.savefig("plot_image_flood_tenders.png", format="png", dpi=300, bbox_inches="tight")  
plt.show()

# %%
# Import matplotlib
import matplotlib.pyplot as plt

# Plot Department Involvement
plt.style.use("fivethirtyeight")
plt.figure(figsize=(10, 6))
count_x = top_5_departments['Tender Count']
department_y = top_5_departments['Department']
plt.barh(department_y, count_x, color='#23B2A7')
plt.xlabel('Number of Tenders')
plt.title('Top Departments Involved in Flood-Related Projects')
plt.savefig("plot_department_involvement.png", format="png", dpi=300, bbox_inches="tight")  
plt.show()

# %%
top_regions_funding = region_funding_sorted.head(5)

# %%
top_regions_funding
# Out:
#                         Location Tender Value in ₹  Tender Count
# 195                   Sundargarh  2,467,096,415.00           164
# 13   Balimela.Malkanagiri,Odisha    901,395,438.00             1
# 35                   Bhanjanagar    282,996,794.00           244
# 176   Rajanagar Block,Kendrapara    244,498,368.00             1
# 4                           Aska    196,424,801.00            40

# %%
# Creating the data as a dictionary
data = {
    'Location': ['Sundargarh', 'Balimela.Malkanagiri,Odisha', 'Bhanjanagar', 'Rajanagar Block,Kendrapara', 'Aska'],
    'Tender Value in ₹': [2467096415.00, 901395438.00, 282996794.00, 244498368.00, 196424801.00],
    'Tender Count': [164, 1, 244, 1, 40]
}

# Convert the dictionary into a pandas DataFrame
df = pd.DataFrame(data)

# Convert 'Tender Value in ₹' to crores
df['Tender Value in Crores'] = df['Tender Value in ₹'] / 10_000_000

# Sorting data by 'Tender Value in Crores' for better visualization
df_sorted = df.sort_values(by='Tender Value in Crores', ascending=False)

# Plotting the bar chart with y-axis in crores
plt.figure(figsize=(10, 6))
plt.bar(df_sorted['Location'], df_sorted['Tender Value in Crores'], color='#23B2A7')

# Adding labels and title
plt.xlabel('Location')
plt.ylabel('Tender Value (in Crores ₹)')
plt.title('Tender Value by Location')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()

# Save the plot as a PNG file
plt.savefig("tender_value_by_location.png", format="png", dpi=300, bbox_inches="tight")

# Show the plot
plt.show()
